# %%
import numpy as np
import Analysis_source as src
from importlib import reload

# %%
fname = 'WSHELL/NP22-53_PRO1_wshellexhange.sfu'
data = src.import_wshell(fname)
# Out:
# 100%|██████████| 107/107 [00:00<00:00, 458886.02it/s]

# %%
src.plot_wshell(data, frac_c=0.946, savefig=True, prefix='Figures/NP22big')
# Out:
# -3.75 e^-1.60x + 0.58
# 94.6% --> (3.00, 0.55)
